# %%
import pandas 
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import sklearn
import scipy.stats as stats
import nbimporter

# %%
# Ensure the module is in the same directory or adjust the path accordingly
from library import  loading_data
    
data = loading_data()

# %%
from library import split_data_halfway
first, second = split_data_halfway(data_num)
#first.head()
second['Which type of stress do you primarily experience?'].unique()
# Out:
# array(['Eustress (Positive Stress) - Stress that motivates and enhances performance.',
#        'No Stress - Currently experiencing minimal to no stress.',
#        'Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.'],
#       dtype=object)

# %%
#make all numeric

data_num = data.replace({
    'Eustress (Positive Stress) - Stress that motivates and enhances performance.': 2,
    'No Stress - Currently experiencing minimal to no stress.': 1,
    'Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.': 0
})
data_num.head()

from library import split_data_halfway
first, second = split_data_halfway(data_num)


#make a heatmap
corr1 = first.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr1, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
corr2 = second.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr2, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
#though the corr isnt especially high, since it has so many data points, it is still significant and can be a good model.
# Out:
# C:\Users\lopke\AppData\Local\Temp\ipykernel_56712\3067924278.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_num = data.replace({

# %%
from library import plot_distro
plot_distro(data_num)

# %%
tot = data_num.iloc[:, -1].value_counts()

tot / tot.sum()
# Out:
# Which type of stress do you primarily experience?
# 2    0.911032
# 1    0.051008
# 0    0.037960
# Name: count, dtype: float64
